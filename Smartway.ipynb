# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import seaborn as sns
import math
import missingno as msn

# %%
input_file_path1 = "/home/emumen/Documents/Misk-DSI-2022/Predicting-and-Analyzing-Fuel-Efficiency/data/Smartway-Vehicle-List/"
output_file_path1 = "/home/emumen/Documents/Misk-DSI-2022/Predicting-and-Analyzing-Fuel-Efficiency/data/"
excel_file_list1 = os.listdir(input_file_path1)
print(excel_file_list1)
# Out:
# ['SmartWay Vehicle List for MY 2016.xlsx', 'SmartWay Vehicle List for MY 2023 (2).xlsx', 'SmartWay Vehicle List for MY 2021.xlsx', 'SmartWay Vehicle List for MY 2014.xlsx', 'SmartWay Vehicle List for MY 2017.xlsx', 'SmartWay Vehicle List for MY 2022.xlsx', 'SmartWay Vehicle List for MY 2015.xlsx', 'SmartWay Vehicle List for MY 2018.xlsx', 'SmartWay Vehicle List for MY 2020.xlsx', 'SmartWay Vehicle List for MY 2019.xlsx', 'SmartWay Vehicle List for MY 2013.xlsx']

# %%
df1 = pd.DataFrame()
for excel_files in excel_file_list1:
     if excel_files.endswith(".xlsx"):
        df2 = pd.read_excel(input_file_path1+excel_files)
        df1 = df1.append(df2)
# Out:
# /tmp/ipykernel_787/3443263923.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(df2)
# /tmp/ipykernel_787/3443263923.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(df2)
# /tmp/ipykernel_787/3443263923.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(df2)
# /tmp/ipykernel_787/3443263923.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(df2)
# /tmp/ipykernel_787/3443263923.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(df2)
# ...

# %%
df1.to_excel(output_file_path1+"Smartway.xlsx")

# %%
smart = pd.read_excel("/home/emumen/Documents/Misk-DSI-2022/Predicting-and-Analyzing-Fuel-Efficiency/data/Smartway.xlsx")
smart.head(1000)
# Out:
#      Unnamed: 0              Model  Displ  Cyl       Trans Drive      Fuel  \
# 0             0          ACURA ILX    2.4  4.0   AutoMan-8   2WD  Gasoline
# 1             1          ACURA RLX    3.5  6.0   AutoMan-7   4WD  Gasoline
# 2             2          ACURA RLX    3.5  6.0   AutoMan-7   4WD  Gasoline
# 3             3          ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline
# 4             4  AUDI A3 Cabriolet    1.8  4.0       AMS-6   2WD  Gasoline
# ..          ...                ...    ...  ...         ...   ...       ...
# 995         331       TOYOTA Venza    2.5  4.0       SCV-6   4WD  Gasoline
# 996         332       TOYOTA Venza    2.5  4.0       SCV-6   4WD  Gasoline
# 997         333    VOLKSWAGEN Golf    1.4  4.0       Man-6   2WD  Gasoline
# 998         334    VOLKSWAGEN Golf    1.4  4.0       Man-6   2WD  Gasoline
# 999         335    VOLKSWAGEN Golf    1.4  4.0  SemiAuto-8   2WD  Gasoline
#
# ...

# %%
smart.describe()
# Out:
#         Unnamed: 0        Displ          Cyl  Air Pollution Score
# count  4905.000000  4090.000000  4090.000000          1801.000000
# mean    238.013660     1.911443     4.052078             7.525819
# std     147.247054     0.489569     0.553321             1.926287
# min       0.000000     0.600000     2.000000             3.000000
# 25%     111.000000     1.600000     4.000000             7.000000
# 50%     231.000000     1.800000     4.000000             7.000000
# 75%     353.000000     2.000000     4.000000            10.000000
# max     611.000000     4.600000     8.000000            10.000000

# %%
smart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4905 entries, 0 to 4904
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             4905 non-null   int64
#  1   Model                  4905 non-null   object
#  2   Displ                  4090 non-null   float64
#  3   Cyl                    4090 non-null   float64
#  4   Trans                  4905 non-null   object
#  5   Drive                  4905 non-null   object
#  6   Fuel                   4905 non-null   object
#  7   Sales Area             3104 non-null   object
#  8   Stnd                   4905 non-null   object
#  9   Stnd Description       4905 non-null   object
#  10  Underhood ID           4905 non-null   object
#  11  Veh Class              4905 non-null   object
#  12  Smog Rating            3104 non-null   object
#  13  City MPG               4905 non-null   object
# ...

# %%
smart.isnull().sum()
# Out:
# Unnamed: 0                  0
# Model                       0
# Displ                     815
# Cyl                       815
# Trans                       0
# Drive                       0
# Fuel                        0
# Sales Area               1801
# Stnd                        0
# Stnd Description            0
# Underhood ID                0
# Veh Class                   0
# Smog Rating              1801
# City MPG                    0
# Hwy MPG                     0
# Cmb MPG                     0
# Greenhouse Gas Score     1138
# SmartWay                    0
# Cert Region              3104
# Air Pollution Score      3104
# Greenhouse Gas Rating    3767
# dtype: int64

# %%
msn.bar(smart)
# Out:
# <AxesSubplot:>

# %%
Columns = []
for column in smart:
    if smart[column].isna().sum() >= 0.75*4905:
#    if msn.bar(column) == 0:
        Columns.append(column)
    else:
        continue
smart.drop(Columns, axis = 1, inplace = True)
#print(Columns)
msn.bar(smart)
# Out:
# <AxesSubplot:>
